# %%
import yfinance as yf
import pandas as pd

# %%
s=yf.Search("Reliance",enable_fuzzy_query=True, lists_count=30,max_results=30
                       news_count=0,
                       )
pd.DataFrame(s.quotes)
# Out:
#   Cell In[2], line 1
#     s=yf.Search("Reliance",enable_fuzzy_query=True, lists_count=30,max_results=30
#                                                                                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
s.__dict__
# Out:
# {'session': None,
#  '_data': <yfinance.data.YfData at 0x753f50ae54c0>,
#  'query': 'Reliance',
#  'max_results': 30,
#  'enable_fuzzy_query': True,
#  'news_count': 8,
#  'timeout': 30,
#  'raise_errors': True,
#  'lists_count': 30,
#  'include_cb': True,
#  'nav_links': False,
#  'enable_research': False,
#  'enable_cultural_assets': False,
#  'recommended': 8,
#  '_logger': <Logger yfinance (WARNING)>,
#  '_response': {'explains': [],
#   'count': 15,
#   'quotes': [{'exchange': 'NYQ',
#     'shortname': 'Reliance, Inc.',
#     'quoteType': 'EQUITY',
#     'symbol': 'RS',
#     'index': 'quotes',
#     'score': 20038.0,
#     'typeDisp': 'Equity',
#     'longname': 'Reliance, Inc.',
#     'exchDisp': 'NYSE',
#     'sector': 'Basic Materials',
#     'sectorDisp': 'Basic Materials',
#     'industry': 'Steel',
#     'industryDisp': 'Steel',
#     'dispSecIndFlag': True,
#     'isYahooFinance': True},
#    {'exchange': 'NSI',
#     'shortname': 'RELIANCE INDUSTRIES LTD',
#     'quoteType': 'EQUITY',
#     'symbol': 'RELIANCE.NS',
#     'index': 'quotes',
#     'score': 20018.0,
#     'typeDisp': 'Equity',
#     'longname': 'Reliance Industries Limited',
#     'exchDisp': 'NSE',
#     'sector': 'Energy',
#     'sectorDisp': 'Energy',
#     'industry': 'Oil & Gas Refining & Marketing',
#     'industryDisp': 'Oil & Gas Refining & Marketing',
#     'isYahooFinance': True},
#    {'exchange': 'NCM',
#     'shortname': 'Reliance Global Group, Inc.',
#     'quoteType': 'EQUITY',
#     'symbol': 'RELI',
#     'index': 'quotes',
#     'score': 20009.0,
#     'typeDisp': 'Equity',
#     'longname': 'Reliance Global Group, Inc.',
#     'exchDisp': 'NASDAQ',
#     'sector': 'Financial Services',
#     'sectorDisp': 'Financial Services',
#     'industry': 'Insurance Brokers',
#     'industryDisp': 'Insurance Brokers',
#     'isYahooFinance': True},
#    {'exchange': 'BSE',
#     'shortname': 'RELIANCE POWER LTD.',
#     'quoteType': 'EQUITY',
#     'symbol': 'RPOWER.BO',
#     'index': 'quotes',
#     'score': 20006.0,
#     'typeDisp': 'Equity',
#     'longname': 'Reliance Power Limited',
#     'exchDisp': 'Bombay',
#     'sector': 'Utilities',
#     'sectorDisp': 'Utilities',
#     'industry': 'Utilities—Independent Power Producers',
#     'industryDisp': 'Utilities—Independent Power Producers',
#     'isYahooFinance': True},
#    {'exchange': 'BSE',
#     'shortname': '0P0000NPMX.BO',
#     'quoteType': 'MUTUALFUND',
#     'symbol': '0P0000NPMX.BO',
#     'index': 'quotes',
#     'score': 20006.0,
#     'typeDisp': 'Fund',
#     'longname': 'Reliance Health Energy Fund 1',
#     'exchDisp': 'Bombay',
#     'isYahooFinance': True},
#    {'index': '1383dbc091202d6730a8a7c652bfa95b',
#     'name': 'Reliance Jio',
#     'permalink': 'reliance-jio-infocomm-ltd-234',
#     'isYahooFinance': False},
#    {'index': '550b988a117d0b3f2cf41ef42235ca05',
#     'name': 'Reliance Retail',
#     'permalink': 'reliance-retail',
#     'isYahooFinance': False}],
#   'news': [{'uuid': '7545abf2-a02d-3dc6-9b5f-462f7101d205',
#     'title': 'Start of Day Message',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/start-day-message-050000755.html',
#     'providerPublishTime': 1759813200,
#     'type': 'STORY'},
#    {'uuid': '636a8b33-be60-31bd-8445-682971d4bd71',
#     'title': 'Unaudited Interim Results for the six months ended 31 July 2025',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/unaudited-interim-results-six-months-060000971.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/cPqM8sN8nanBlfvJsmbTLQ--~B/aD02Mjg7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/afd8879296de01c3cf4898ccb4cad30c',
#        'width': 1200,
#        'height': 628,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/c_CiZY8iDp8apBKjArv4FQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/afd8879296de01c3cf4898ccb4cad30c',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]},
#     'relatedTickers': ['ICGT.L']},
#    {'uuid': '14474a58-02e2-3c9a-ad38-47184ce55d5d',
#     'title': 'Pharmaceutical Market Size Worth USD 3.03 Trillion by 2034',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/pharmaceutical-market-size-worth-usd-062700083.html',
#     'providerPublishTime': 1759818420,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/hdxZCkfUK4GBULpLUEY2iA--~B/aD0xNjY3O3c9MTY2NzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/47160fa420d06f24420d9a27698245a7',
#        'width': 1667,
#        'height': 1667,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/6in_GXZ45Nm.zaynM5f2.g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/47160fa420d06f24420d9a27698245a7',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]}},
#    {'uuid': '7fb09181-55ed-358d-9850-f3d55f558874',
#     'title': 'Tacton Acquires Variantum and Serenytics to Deliver the Most Complete End-to-End Platform for Complex Manufacturers',
#     'publisher': 'Business Wire',
#     'link': 'https://finance.yahoo.com/news/tacton-acquires-variantum-serenytics-deliver-060000080.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/c3QBriJPieK8dR8O.mymiQ--~B/aD01MTk7dz0yNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/18bd431c78be2e905c631068128e963e',
#        'width': 2400,
#        'height': 519,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/jaKYvnYTlm70EzntNXjjHA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/18bd431c78be2e905c631068128e963e',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]}},
#    {'uuid': '3ef01ea4-73a6-3a47-81d2-675dad6b0060',
#     'title': 'NBPE - Transaction in Own Shares',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/nbpe-transaction-own-shares-060000805.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/3igBVPD.sAv8SMZWIKkjmg--~B/aD03ODt3PTQ0MzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/26853bc34382499a34640cc1905a1de6',
#        'width': 443,
#        'height': 78,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/EtsTcbhKz7bRPvy7xag9QA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/26853bc34382499a34640cc1905a1de6',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]},
#     'relatedTickers': ['NBPVF', 'NBPE.L']},
#    {'uuid': '40541a0b-3c13-3912-97ba-384e31e2e234',
#     'title': 'Kosmos Energy to Host Third Quarter 2025 Results and Webcast on November 03, 2025',
#     'publisher': 'Business Wire',
#     'link': 'https://finance.yahoo.com/news/kosmos-energy-host-third-quarter-060000913.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Pg_DcInfhGPtjW1mAILVXg--~B/aD0yMzg7dz04NjQ7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/business-wire.com/f6896bd89773de6f8f907755bc823913',
#        'width': 864,
#        'height': 238,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/XcC51mqilw7iaSGpRxy.gg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/f6896bd89773de6f8f907755bc823913',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]},
#     'relatedTickers': ['KOS']},
#    {'uuid': 'ac035faa-9b9a-3c84-8ddf-276ceda1ddd4',
#     'title': 'Edf: EDF announces the final results of its tender offer for two series of outstanding hybrid notes',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/edf-edf-announces-final-results-060000343.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/k02eFCZbMPxAzQuAmh.jog--~B/aD05MTt3PTE1MzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/81eaab2422733ed0f1fae15920931fce',
#        'width': 153,
#        'height': 91,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/OFXcjfaKxjlkzTBdY4OZiA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/81eaab2422733ed0f1fae15920931fce',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]}},
#    {'uuid': 'd23fa098-c693-3b89-a30c-7665c70810f8',
#     'title': 'Shell third quarter 2025 update note',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/shell-third-quarter-2025-note-060000286.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'relatedTickers': ['RYDAF', 'SHEL', 'SHEL.L']}],
#   'nav': [],
#   'lists': [],
#   'researchReports': [],
#   'screenerFieldResults': [],
#   'totalTime': 43,
#   'timeTakenForQuotes': 433,
#   'timeTakenForNews': 900,
#   'timeTakenForAlgowatchlist': 400,
#   'timeTakenForPredefinedScreener': 400,
#   'timeTakenForCrunchbase': 400,
#   'timeTakenForNav': 0,
#   'timeTakenForResearchReports': 0,
#   'timeTakenForScreenerField': 0,
#   'timeTakenForCulturalAssets': 0,
#   'timeTakenForSearchLists': 0},
#  '_all': {'quotes': [{'exchange': 'NYQ',
#     'shortname': 'Reliance, Inc.',
#     'quoteType': 'EQUITY',
#     'symbol': 'RS',
#     'index': 'quotes',
#     'score': 20038.0,
#     'typeDisp': 'Equity',
#     'longname': 'Reliance, Inc.',
#     'exchDisp': 'NYSE',
#     'sector': 'Basic Materials',
#     'sectorDisp': 'Basic Materials',
#     'industry': 'Steel',
#     'industryDisp': 'Steel',
#     'dispSecIndFlag': True,
#     'isYahooFinance': True},
#    {'exchange': 'NSI',
#     'shortname': 'RELIANCE INDUSTRIES LTD',
#     'quoteType': 'EQUITY',
#     'symbol': 'RELIANCE.NS',
#     'index': 'quotes',
#     'score': 20018.0,
#     'typeDisp': 'Equity',
#     'longname': 'Reliance Industries Limited',
#     'exchDisp': 'NSE',
#     'sector': 'Energy',
#     'sectorDisp': 'Energy',
#     'industry': 'Oil & Gas Refining & Marketing',
#     'industryDisp': 'Oil & Gas Refining & Marketing',
#     'isYahooFinance': True},
#    {'exchange': 'NCM',
#     'shortname': 'Reliance Global Group, Inc.',
#     'quoteType': 'EQUITY',
#     'symbol': 'RELI',
#     'index': 'quotes',
#     'score': 20009.0,
#     'typeDisp': 'Equity',
#     'longname': 'Reliance Global Group, Inc.',
#     'exchDisp': 'NASDAQ',
#     'sector': 'Financial Services',
#     'sectorDisp': 'Financial Services',
#     'industry': 'Insurance Brokers',
#     'industryDisp': 'Insurance Brokers',
#     'isYahooFinance': True},
#    {'exchange': 'BSE',
#     'shortname': 'RELIANCE POWER LTD.',
#     'quoteType': 'EQUITY',
#     'symbol': 'RPOWER.BO',
#     'index': 'quotes',
#     'score': 20006.0,
#     'typeDisp': 'Equity',
#     'longname': 'Reliance Power Limited',
#     'exchDisp': 'Bombay',
#     'sector': 'Utilities',
#     'sectorDisp': 'Utilities',
#     'industry': 'Utilities—Independent Power Producers',
#     'industryDisp': 'Utilities—Independent Power Producers',
#     'isYahooFinance': True},
#    {'exchange': 'BSE',
#     'shortname': '0P0000NPMX.BO',
#     'quoteType': 'MUTUALFUND',
#     'symbol': '0P0000NPMX.BO',
#     'index': 'quotes',
#     'score': 20006.0,
#     'typeDisp': 'Fund',
#     'longname': 'Reliance Health Energy Fund 1',
#     'exchDisp': 'Bombay',
#     'isYahooFinance': True}],
#   'news': [{'uuid': '7545abf2-a02d-3dc6-9b5f-462f7101d205',
#     'title': 'Start of Day Message',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/start-day-message-050000755.html',
#     'providerPublishTime': 1759813200,
#     'type': 'STORY'},
#    {'uuid': '636a8b33-be60-31bd-8445-682971d4bd71',
#     'title': 'Unaudited Interim Results for the six months ended 31 July 2025',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/unaudited-interim-results-six-months-060000971.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/cPqM8sN8nanBlfvJsmbTLQ--~B/aD02Mjg7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/afd8879296de01c3cf4898ccb4cad30c',
#        'width': 1200,
#        'height': 628,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/c_CiZY8iDp8apBKjArv4FQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/afd8879296de01c3cf4898ccb4cad30c',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]},
#     'relatedTickers': ['ICGT.L']},
#    {'uuid': '14474a58-02e2-3c9a-ad38-47184ce55d5d',
#     'title': 'Pharmaceutical Market Size Worth USD 3.03 Trillion by 2034',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/pharmaceutical-market-size-worth-usd-062700083.html',
#     'providerPublishTime': 1759818420,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/hdxZCkfUK4GBULpLUEY2iA--~B/aD0xNjY3O3c9MTY2NzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/47160fa420d06f24420d9a27698245a7',
#        'width': 1667,
#        'height': 1667,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/6in_GXZ45Nm.zaynM5f2.g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/47160fa420d06f24420d9a27698245a7',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]}},
#    {'uuid': '7fb09181-55ed-358d-9850-f3d55f558874',
#     'title': 'Tacton Acquires Variantum and Serenytics to Deliver the Most Complete End-to-End Platform for Complex Manufacturers',
#     'publisher': 'Business Wire',
#     'link': 'https://finance.yahoo.com/news/tacton-acquires-variantum-serenytics-deliver-060000080.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/c3QBriJPieK8dR8O.mymiQ--~B/aD01MTk7dz0yNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/18bd431c78be2e905c631068128e963e',
#        'width': 2400,
#        'height': 519,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/jaKYvnYTlm70EzntNXjjHA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/18bd431c78be2e905c631068128e963e',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]}},
#    {'uuid': '3ef01ea4-73a6-3a47-81d2-675dad6b0060',
#     'title': 'NBPE - Transaction in Own Shares',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/nbpe-transaction-own-shares-060000805.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/3igBVPD.sAv8SMZWIKkjmg--~B/aD03ODt3PTQ0MzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/26853bc34382499a34640cc1905a1de6',
#        'width': 443,
#        'height': 78,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/EtsTcbhKz7bRPvy7xag9QA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/26853bc34382499a34640cc1905a1de6',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]},
#     'relatedTickers': ['NBPVF', 'NBPE.L']},
#    {'uuid': '40541a0b-3c13-3912-97ba-384e31e2e234',
#     'title': 'Kosmos Energy to Host Third Quarter 2025 Results and Webcast on November 03, 2025',
#     'publisher': 'Business Wire',
#     'link': 'https://finance.yahoo.com/news/kosmos-energy-host-third-quarter-060000913.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Pg_DcInfhGPtjW1mAILVXg--~B/aD0yMzg7dz04NjQ7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/business-wire.com/f6896bd89773de6f8f907755bc823913',
#        'width': 864,
#        'height': 238,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/XcC51mqilw7iaSGpRxy.gg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/f6896bd89773de6f8f907755bc823913',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]},
#     'relatedTickers': ['KOS']},
#    {'uuid': 'ac035faa-9b9a-3c84-8ddf-276ceda1ddd4',
#     'title': 'Edf: EDF announces the final results of its tender offer for two series of outstanding hybrid notes',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/edf-edf-announces-final-results-060000343.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/k02eFCZbMPxAzQuAmh.jog--~B/aD05MTt3PTE1MzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/81eaab2422733ed0f1fae15920931fce',
#        'width': 153,
#        'height': 91,
#        'tag': 'original'},
#       {'url': 'https://s.yimg.com/uu/api/res/1.2/OFXcjfaKxjlkzTBdY4OZiA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/81eaab2422733ed0f1fae15920931fce',
#        'width': 140,
#        'height': 140,
#        'tag': '140x140'}]}},
#    {'uuid': 'd23fa098-c693-3b89-a30c-7665c70810f8',
#     'title': 'Shell third quarter 2025 update note',
#     'publisher': 'GlobeNewswire',
#     'link': 'https://finance.yahoo.com/news/shell-third-quarter-2025-note-060000286.html',
#     'providerPublishTime': 1759816800,
#     'type': 'STORY',
#     'relatedTickers': ['RYDAF', 'SHEL', 'SHEL.L']}],
#   'lists': [],
#   'research': [],
#   'nav': []},
#  '_quotes': [{'exchange': 'NYQ',
#    'shortname': 'Reliance, Inc.',
#    'quoteType': 'EQUITY',
#    'symbol': 'RS',
#    'index': 'quotes',
#    'score': 20038.0,
#    'typeDisp': 'Equity',
#    'longname': 'Reliance, Inc.',
#    'exchDisp': 'NYSE',
#    'sector': 'Basic Materials',
#    'sectorDisp': 'Basic Materials',
#    'industry': 'Steel',
#    'industryDisp': 'Steel',
#    'dispSecIndFlag': True,
#    'isYahooFinance': True},
#   {'exchange': 'NSI',
#    'shortname': 'RELIANCE INDUSTRIES LTD',
#    'quoteType': 'EQUITY',
#    'symbol': 'RELIANCE.NS',
#    'index': 'quotes',
#    'score': 20018.0,
#    'typeDisp': 'Equity',
#    'longname': 'Reliance Industries Limited',
#    'exchDisp': 'NSE',
#    'sector': 'Energy',
#    'sectorDisp': 'Energy',
#    'industry': 'Oil & Gas Refining & Marketing',
#    'industryDisp': 'Oil & Gas Refining & Marketing',
#    'isYahooFinance': True},
#   {'exchange': 'NCM',
#    'shortname': 'Reliance Global Group, Inc.',
#    'quoteType': 'EQUITY',
#    'symbol': 'RELI',
#    'index': 'quotes',
#    'score': 20009.0,
#    'typeDisp': 'Equity',
#    'longname': 'Reliance Global Group, Inc.',
#    'exchDisp': 'NASDAQ',
#    'sector': 'Financial Services',
#    'sectorDisp': 'Financial Services',
#    'industry': 'Insurance Brokers',
#    'industryDisp': 'Insurance Brokers',
#    'isYahooFinance': True},
#   {'exchange': 'BSE',
#    'shortname': 'RELIANCE POWER LTD.',
#    'quoteType': 'EQUITY',
#    'symbol': 'RPOWER.BO',
#    'index': 'quotes',
#    'score': 20006.0,
#    'typeDisp': 'Equity',
#    'longname': 'Reliance Power Limited',
#    'exchDisp': 'Bombay',
#    'sector': 'Utilities',
#    'sectorDisp': 'Utilities',
#    'industry': 'Utilities—Independent Power Producers',
#    'industryDisp': 'Utilities—Independent Power Producers',
#    'isYahooFinance': True},
#   {'exchange': 'BSE',
#    'shortname': '0P0000NPMX.BO',
#    'quoteType': 'MUTUALFUND',
#    'symbol': '0P0000NPMX.BO',
#    'index': 'quotes',
#    'score': 20006.0,
#    'typeDisp': 'Fund',
#    'longname': 'Reliance Health Energy Fund 1',
#    'exchDisp': 'Bombay',
#    'isYahooFinance': True}],
#  '_news': [{'uuid': '7545abf2-a02d-3dc6-9b5f-462f7101d205',
#    'title': 'Start of Day Message',
#    'publisher': 'GlobeNewswire',
#    'link': 'https://finance.yahoo.com/news/start-day-message-050000755.html',
#    'providerPublishTime': 1759813200,
#    'type': 'STORY'},
#   {'uuid': '636a8b33-be60-31bd-8445-682971d4bd71',
#    'title': 'Unaudited Interim Results for the six months ended 31 July 2025',
#    'publisher': 'GlobeNewswire',
#    'link': 'https://finance.yahoo.com/news/unaudited-interim-results-six-months-060000971.html',
#    'providerPublishTime': 1759816800,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/cPqM8sN8nanBlfvJsmbTLQ--~B/aD02Mjg7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/afd8879296de01c3cf4898ccb4cad30c',
#       'width': 1200,
#       'height': 628,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/c_CiZY8iDp8apBKjArv4FQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/afd8879296de01c3cf4898ccb4cad30c',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['ICGT.L']},
#   {'uuid': '14474a58-02e2-3c9a-ad38-47184ce55d5d',
#    'title': 'Pharmaceutical Market Size Worth USD 3.03 Trillion by 2034',
#    'publisher': 'GlobeNewswire',
#    'link': 'https://finance.yahoo.com/news/pharmaceutical-market-size-worth-usd-062700083.html',
#    'providerPublishTime': 1759818420,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/hdxZCkfUK4GBULpLUEY2iA--~B/aD0xNjY3O3c9MTY2NzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/47160fa420d06f24420d9a27698245a7',
#       'width': 1667,
#       'height': 1667,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/6in_GXZ45Nm.zaynM5f2.g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/47160fa420d06f24420d9a27698245a7',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]}},
#   {'uuid': '7fb09181-55ed-358d-9850-f3d55f558874',
#    'title': 'Tacton Acquires Variantum and Serenytics to Deliver the Most Complete End-to-End Platform for Complex Manufacturers',
#    'publisher': 'Business Wire',
#    'link': 'https://finance.yahoo.com/news/tacton-acquires-variantum-serenytics-deliver-060000080.html',
#    'providerPublishTime': 1759816800,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/c3QBriJPieK8dR8O.mymiQ--~B/aD01MTk7dz0yNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/18bd431c78be2e905c631068128e963e',
#       'width': 2400,
#       'height': 519,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/jaKYvnYTlm70EzntNXjjHA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/18bd431c78be2e905c631068128e963e',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]}},
#   {'uuid': '3ef01ea4-73a6-3a47-81d2-675dad6b0060',
#    'title': 'NBPE - Transaction in Own Shares',
#    'publisher': 'GlobeNewswire',
#    'link': 'https://finance.yahoo.com/news/nbpe-transaction-own-shares-060000805.html',
#    'providerPublishTime': 1759816800,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/3igBVPD.sAv8SMZWIKkjmg--~B/aD03ODt3PTQ0MzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/26853bc34382499a34640cc1905a1de6',
#       'width': 443,
#       'height': 78,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/EtsTcbhKz7bRPvy7xag9QA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/26853bc34382499a34640cc1905a1de6',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['NBPVF', 'NBPE.L']},
#   {'uuid': '40541a0b-3c13-3912-97ba-384e31e2e234',
#    'title': 'Kosmos Energy to Host Third Quarter 2025 Results and Webcast on November 03, 2025',
#    'publisher': 'Business Wire',
#    'link': 'https://finance.yahoo.com/news/kosmos-energy-host-third-quarter-060000913.html',
#    'providerPublishTime': 1759816800,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Pg_DcInfhGPtjW1mAILVXg--~B/aD0yMzg7dz04NjQ7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/business-wire.com/f6896bd89773de6f8f907755bc823913',
#       'width': 864,
#       'height': 238,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/XcC51mqilw7iaSGpRxy.gg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/f6896bd89773de6f8f907755bc823913',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]},
#    'relatedTickers': ['KOS']},
#   {'uuid': 'ac035faa-9b9a-3c84-8ddf-276ceda1ddd4',
#    'title': 'Edf: EDF announces the final results of its tender offer for two series of outstanding hybrid notes',
#    'publisher': 'GlobeNewswire',
#    'link': 'https://finance.yahoo.com/news/edf-edf-announces-final-results-060000343.html',
#    'providerPublishTime': 1759816800,
#    'type': 'STORY',
#    'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/k02eFCZbMPxAzQuAmh.jog--~B/aD05MTt3PTE1MzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/81eaab2422733ed0f1fae15920931fce',
#       'width': 153,
#       'height': 91,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/OFXcjfaKxjlkzTBdY4OZiA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/81eaab2422733ed0f1fae15920931fce',
#       'width': 140,
#       'height': 140,
#       'tag': '140x140'}]}},
#   {'uuid': 'd23fa098-c693-3b89-a30c-7665c70810f8',
#    'title': 'Shell third quarter 2025 update note',
#    'publisher': 'GlobeNewswire',
#    'link': 'https://finance.yahoo.com/news/shell-third-quarter-2025-note-060000286.html',
#    'providerPublishTime': 1759816800,
#    'type': 'STORY',
#    'relatedTickers': ['RYDAF', 'SHEL', 'SHEL.L']}],
#  '_lists': [],
#  '_research': [],
#  '_nav': []}

# %%
l=yf.Lookup("Reliance").get_all()
l.__dict__
# Out:
# {'_is_copy': None,
#  '_mgr': BlockManager
#  Items: Index(['exchange', 'industryLink', 'industryName', 'quoteType', 'rank',
#         'regularMarketChange', 'regularMarketPercentChange',
#         'regularMarketPrice', 'shortName'],
#        dtype='object')
#  Axis 1: Index(['RS', 'RELIANCE.NS', 'RELI', 'RPOWER.BO', '0P0000NPMX.BO',
#         '0P0000TGJZ.BO', '0EU.F', '0P0000NPP0.BO', 'RELIW', '0P0000NPLM.BO',
#         '0P0000NPKG.BO', 'RS6.DU', 'RELIANCE.BO', 'RELI.JK', 'RELINFRA.NS',
#         '0P0000TGKS.BO', 'FSRL', 'RIGDL.XC', 'RWC.AX', 'RLI.MU', 'RS6.BE',
#         'RHFL.BO', '0EU.BE', 'RCOM.BO', '0P0000P3WT.TW'],
#        dtype='object', name='symbol')
#  NumpyBlock: slice(0, 4, 1), 4 x 25, dtype: object
#  NumpyBlock: slice(4, 5, 1), 1 x 25, dtype: int64
#  NumpyBlock: slice(5, 8, 1), 3 x 25, dtype: float64
#  NumpyBlock: slice(8, 9, 1), 1 x 25, dtype: object,
#  '_item_cache': {},
#  '_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>}

# %%
exchanges=['BSE','NSI']
l.query('exchange.isin(@exchanges)')["quoteType shortName".split()]
# Out:
#                 quoteType                      shortName
# symbol
# RELIANCE.NS        equity        RELIANCE INDUSTRIES LTD
# RPOWER.BO          equity            RELIANCE POWER LTD.
# 0P0000NPMX.BO  mutualfund                  0P0000NPMX.BO
# 0P0000TGJZ.BO  mutualfund                  0P0000TGJZ.BO
# 0P0000NPP0.BO  mutualfund                  0P0000NPP0.BO
# 0P0000NPLM.BO  mutualfund                  0P0000NPLM.BO
# 0P0000NPKG.BO  mutualfund                  0P0000NPKG.BO
# RELIANCE.BO        equity       RELIANCE INDUSTRIES LTD.
# RELINFRA.NS        equity      RELIANCE INFRASTRUCTU LTD
# 0P0000TGKS.BO  mutualfund                  0P0000TGKS.BO
# RHFL.BO            equity  Reliance Home Finance Limited
# RCOM.BO            equity   RELIANCE COMMUNICATIONS LTD.

# %%
s=yf.Ticker('0P0001PR8B.BO')

# %%
s.info
# Out:
# {'address1': 'Bandra (East), Mumbai',
#  'address2': 'C-38 & 39, G Block, Bandra Kurla Complex,',
#  'address3': '9th Floor, Crescenzo,',
#  'phone': '022 - 61793000',
#  'companyOfficers': [],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 18.5528,
#  'regularMarketPreviousClose': 18.5528,
#  'trailingPE': 28.943983,
#  'yield': 0.0,
#  'ytdReturn': -6.91712,
#  'fiftyTwoWeekLow': 14.9928,
#  'fiftyTwoWeekHigh': 20.1718,
#  'fiftyDayAverage': 18.512434,
#  'twoHundredDayAverage': 17.856035,
#  'currency': 'INR',
#  'tradeable': False,
#  'morningStarOverallRating': 0,
#  'morningStarRiskRating': 0,
#  'annualReportExpenseRatio': 0.0,
#  'fundInceptionDate': 1663718400,
#  'annualHoldingsTurnover': 0.40919998,
#  'quoteType': 'MUTUALFUND',
#  'symbol': '0P0001PR8B.BO',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Fund',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'NONE',
#  'shortName': '0P0001PR8B.BO',
#  'longName': 'SBI Nifty Smallcap 250 Index Dir IDCW-T',
#  'marketState': 'POSTPOST',
#  'fiftyDayAverageChange': 0.055965424,
#  'fiftyDayAverageChangePercent': 0.0030231262,
#  'twoHundredDayAverageChange': 0.7123642,
#  'twoHundredDayAverageChangePercent': 0.03989487,
#  'sourceInterval': 10,
#  'exchangeDataDelayedBy': 15,
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1663731900000,
#  'regularMarketChange': 0.0156002045,
#  'fullExchangeName': 'BSE',
#  'fiftyTwoWeekLowChange': 3.5755997,
#  'fiftyTwoWeekLowChangePercent': 0.2384878,
#  'fiftyTwoWeekRange': '14.9928 - 20.1718',
#  'fiftyTwoWeekHighChange': -1.6034012,
#  'fiftyTwoWeekHighChangePercent': -0.079487264,
#  'fiftyTwoWeekChangePercent': -5.897975,
#  'dividendYield': 0.0,
#  'trailingThreeMonthReturns': -1.74247,
#  'epsTrailingTwelveMonths': 0.64152884,
#  'corporateActions': [],
#  'regularMarketTime': 1759708800,
#  'exchange': 'BSE',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'gmtOffSetMilliseconds': 19800000,
#  'market': 'in_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': 0.08408545,
#  'regularMarketPrice': 18.5684,
#  'trailingPegRatio': None}
